# %% [markdown]
# First imported the libraries and loaded the dataset which is related to the food delivery data based on all conditions

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\DELL\\Downloads\\regisuniversity\\data engineering\\Food_Time_Data_Set.csv')

# %%
import seaborn as sns
import pandas as pd

# %%
df
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                 37.0                      4.9
# 1      B379     BANGRES18DEL02                 34.0                      4.5
# 2      5D6D     BANGRES19DEL01                 23.0                      4.4
# 3      7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4      70A2     CHENRES12DEL01                 32.0                      4.6
# ...     ...                ...                  ...                      ...
# 9996   11B4      VADRES13DEL03                 32.0                      4.2
# 9997   8336      HYDRES20DEL01                 36.0                      4.7
# 9998   338B      JAPRES18DEL03                 37.0                      4.6
# 9999   3FB2      MUMRES11DEL03                 29.0                      4.7
# 10000   NaN                NaN                  NaN                      NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           10000 non-null  object
#  1   Delivery_person_ID           10000 non-null  object
#  2   Delivery_person_Age          10000 non-null  float64
#  3   Delivery_person_Ratings      10000 non-null  float64
#  4   Restaurant_latitude          10000 non-null  float64
#  5   Restaurant_longitude         10000 non-null  float64
#  6   Delivery_location_latitude   10000 non-null  float64
#  7   Delivery_location_longitude  10000 non-null  float64
#  8   Type_of_order                10000 non-null  object
#  9   Type_of_vehicle              10000 non-null  object
#  10  temperature                  9995 non-null   float64
#  11  humidity                     9995 non-null   float64
# ...

# %%
df.describe(include = 'all')
# Out:
#               ID Delivery_person_ID  Delivery_person_Age  \
# count      10000              10000         10000.000000
# unique      9995               1285                  NaN
# top     6.00E+02      SURRES16DEL01                  NaN
# freq           2                 22                  NaN
# mean         NaN                NaN            29.522000
# std          NaN                NaN             5.700348
# min          NaN                NaN            15.000000
# 25%          NaN                NaN            25.000000
# 50%          NaN                NaN            29.000000
# 75%          NaN                NaN            34.000000
# max          NaN                NaN            50.000000
#
#         Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# count              10000.000000         10000.000000          10000.000000
# unique                      NaN                  NaN                   NaN
# ...

# %%
data = {
    "Column Name": [
        "ID",
        "Delivery_person_ID",
        "Delivery_person_Age",
        "Delivery_person_Ratings",
        "Restaurant_latitude",
        "Restaurant_longitude",
        "Delivery_location_latitude",
        "Delivery_location_longitude",
        "Type_of_order",
        "Type_of_vehicle",
        "temperature",
        "humidity",
        "precipitation",
        "weather_description",
        "Unnamed: 14",
        "Traffic_Level",
        "Distance (km)",
        "TARGET"
    ],
    "Data Type": [
        "object",
        "object",
        "float64",
        "float64",
        "float64",
        "float64",
        "float64",
        "float64",
        "object",
        "object",
        "float64",
        "float64",
        "float64",
        "object",
        "float64",
        "object",
        "float64",
        "object"
    ],
    "Classification": [
        "Categorical",
        "Categorical",
        "Continuous",
        "Continuous",
        "Continuous",
        "Continuous",
        "Continuous",
        "Continuous",
        "Categorical",
        "Categorical",
        "Continuous",
        "Continuous",
        "Continuous",
        "Categorical",
        "N/A (Empty Column)",
        "Categorical",
        "Continuous",
        "Categorical"
    ],
    "Description": [
        "Unique ID for each record.",
        "ID of the delivery person.",
        "Age of the delivery person.",
        "Ratings given to the delivery person.",
        "Latitude of the restaurant.",
        "Longitude of the restaurant.",
        "Latitude of the delivery location.",
        "Longitude of the delivery location.",
        "Type of order being delivered (e.g., Food, Grocery).",
        "Type of vehicle used for delivery.",
        "Temperature at the time of delivery.",
        "Humidity at the time of delivery.",
        "Precipitation level at the time of delivery.",
        "Description of the weather (e.g., Clear, Rainy).",
        "Column with no data (unnamed).",
        "Traffic level during the delivery (e.g., Low, Medium, High).",
        "Distance of the delivery route in kilometers.",
        "Target variable indicating the status or outcome of the delivery."
    ]
}

classification = pd.DataFrame(data)
classification
# Out:
#                     Column Name Data Type      Classification  \
# 0                            ID    object         Categorical
# 1            Delivery_person_ID    object         Categorical
# 2           Delivery_person_Age   float64          Continuous
# 3       Delivery_person_Ratings   float64          Continuous
# 4           Restaurant_latitude   float64          Continuous
# 5          Restaurant_longitude   float64          Continuous
# 6    Delivery_location_latitude   float64          Continuous
# 7   Delivery_location_longitude   float64          Continuous
# 8                 Type_of_order    object         Categorical
# 9               Type_of_vehicle    object         Categorical
# 10                  temperature   float64          Continuous
# 11                     humidity   float64          Continuous
# 12                precipitation   float64          Continuous
# 13          weather_description    object         Categorical
# ...

# %%
df.head(10)
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                 37.0                      4.9
# 1  B379     BANGRES18DEL02                 34.0                      4.5
# 2  5D6D     BANGRES19DEL01                 23.0                      4.4
# 3  7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4  70A2     CHENRES12DEL01                 32.0                      4.6
# 5  9BB4      HYDRES09DEL03                 22.0                      4.8
# 6  95B4   RANCHIRES15DEL01                 33.0                      4.7
# 7  9EB2      MYSRES15DEL02                 35.0                      4.6
# 8  1102      HYDRES05DEL02                 22.0                      4.8
# 9  CDCD      DEHRES17DEL01                 36.0                      4.2
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# ...

# %% [markdown]
# ### Loading data

# %%
df.shape
# Out:
# (10001, 18)

# %%
pip install psycopg2

# %%
from sqlalchemy import create_engine

# %%
# Note:: The make sure you use the information from your specific PostgreSQL installation
host = r'127.0.0.1' # denotes that the db in a local installation
db = r'msds610' # db we just created
user = r'postgres' # using the postgres user for this demo
pw = r'Harideep' # this is the password established during installation
port = r'5432' # default port estabalished during install
schema = r'raw' # schema we just created

# %%
db_conn = create_engine("postgresql://{}:{}@{}:{}/{}".format(user, pw, host, port, db))

# %%
sql="select tables.table_name from information_schema.tables where (table_schema ='"+schema+"')order by 1;"
tbl_df = pd.read_sql(sql, db_conn, index_col=None)
tbl_df
# Out:
# Empty DataFrame
# Columns: [table_name]
# Index: []

# %%
table_name = r'delivery_data'

# %%
df.to_sql(table_name, con=db_conn, if_exists='replace', index=False, schema=schema, chunksize=1000, method='multi')
# Out:
# 10001

# %%
tbl_df = pd.read_sql(sql, db_conn, index_col=None)
tbl_df
# Out:
#       table_name
# 0  delivery_data

# %% [markdown]
# ### Retrieving data

# %%
sql = f"SELECT table_name FROM information_schema.tables WHERE table_schema = '{schema}' ORDER BY 1;"
tables = pd.read_sql(sql, db_conn)
df = pd.read_sql(sql, db_conn, index_col=None)
# Display the DataFrame
df.head()
# Out:
#       table_name
# 0  delivery_data

# %%
df.head(10)
# Out:
#       table_name
# 0  delivery_data

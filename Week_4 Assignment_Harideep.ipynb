# %% [markdown]
# <img align="right" style="padding-left:50px;" src="figures_wk4/data_cleaning.png" width=350><br>
# ### User Bias in Data Cleaning
# For your homework assignment this week, we will explore how our treatment of our data can impact the quality of our results.
#
# **Dataset:**
# The data is a Salary Survey from AskAManager.org. It’s US-centric-ish but does allow for a range of country inputs.
#
# A list of the corresponding survey questions can be found [here](https://www.askamanager.org/2021/04/how-much-money-do-you-make-4.html).

# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('survey_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28108 entries, 0 to 28107
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  28108 non-null  object
#  1   q1         28108 non-null  object
#  2   q2         28033 non-null  object
#  3   q3         28107 non-null  object
#  4   q4         7273 non-null   object
#  5   q5         28108 non-null  object
#  6   q6         20793 non-null  float64
#  7   q7         28108 non-null  object
#  8   q8         211 non-null    object
#  9   q9         3047 non-null   object
#  10  q10        28108 non-null  object
#  11  q11        23074 non-null  object
#  12  q12        28026 non-null  object
#  13  q13        28108 non-null  object
#  14  q14        28108 non-null  object
#  15  q15        27885 non-null  object
#  16  q16        27937 non-null  object
#  17  q17        27931 non-null  object
# dtypes: float64(1), object(17)
# memory usage: 3.9+ MB

# %%
df.head()
# Out:
#             timestamp     q1                             q2  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                          q3   q4      q5      q6   q7   q8  \
# 0        Research and Instruction Librarian  NaN  55,000     0.0  USD  NaN
# 1  Change & Internal Communications Manager  NaN  54,600  4000.0  GBP  NaN
# 2                      Marketing Specialist  NaN  34,000     NaN  USD  NaN
# 3                           Program Manager  NaN  62,000  3000.0  USD  NaN
# 4                        Accounting Manager  NaN  60,000  7000.0  USD  NaN
#
#     q9             q10             q11          q12           q13  \
# 0  NaN   United States   Massachusetts       Boston     5-7 years
# ...

# %% [markdown]
# ### Assignment
# Your goal for this assignment is to observe how your data treatment during the cleaning process can skew or bias the dataset.
#
# Before diving right in, stop and read through the questions associated with the dataset. As you can see, they are either free-form text entries or categorical selections. Knowing this, perform some exploratory data analysis (EDA) to investigate the "state" of the dataset.
#
# [Add as many code cell below here as needs]

# %%
# mapping questions with proper names for better analysis and data understanding
column_mapping = {
    "q1": "age",
    "q2": "industry",
    "q3": "job_title",
    "q4": "job_title_context",
    "q5": "annual_salary",
    "q6": "additional_compensation",
    "q7": "currency",
    "q8": "currency_other",
    "q9": "income_context",
    "q10": "country",
    "q11": "us_state",
    "q12": "city",
    "q13": "total_experience",
    "q14": "field_experience",
    "q15": "education_level",
    "q16": "gender",
    "q17": "race"
}

df = df.rename(columns=column_mapping)
df.head()
# Out:
#             timestamp    age                       industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                   job_title job_title_context annual_salary  \
# 0        Research and Instruction Librarian               NaN        55,000
# 1  Change & Internal Communications Manager               NaN        54,600
# 2                      Marketing Specialist               NaN        34,000
# 3                           Program Manager               NaN        62,000
# 4                        Accounting Manager               NaN        60,000
#
#    additional_compensation currency currency_other income_context  \
# 0                      0.0      USD            NaN            NaN
# ...

# %%
df.shape
# Out:
# (28108, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28108 entries, 0 to 28107
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                28108 non-null  object
#  1   age                      28108 non-null  object
#  2   industry                 28033 non-null  object
#  3   job_title                28107 non-null  object
#  4   job_title_context        7273 non-null   object
#  5   annual_salary            28108 non-null  object
#  6   additional_compensation  20793 non-null  float64
#  7   currency                 28108 non-null  object
#  8   currency_other           211 non-null    object
#  9   income_context           3047 non-null   object
#  10  country                  28108 non-null  object
#  11  us_state                 23074 non-null  object
#  12  city                     28026 non-null  object
#  13  total_experience         28108 non-null  object
# ...

# %%
# unique values in the dataset
for col in df.columns:
    print(col)
    print(df[col].nunique())
    print()
# Out:
# timestamp
# 25326
#
# age
# 7
#
# industry
# 1220
#
# job_title
# 14377
#
# job_title_context
# 7010
#
# annual_salary
# 4319
#
# additional_compensation
# 848
#
# currency
# 11
#
# currency_other
# 124
#
# income_context
# 2983
#
# country
# 382
#
# us_state
# 137
#
# city
# 4841
#
# total_experience
# 8
#
# field_experience
# 8
#
# education_level
# 6
#
# gender
# 5
#
# race
# 51

# %%
# Null values in the dataset
df.isnull().sum()
# Out:
# timestamp                      0
# age                            0
# industry                      75
# job_title                      1
# job_title_context          20835
# annual_salary                  0
# additional_compensation     7315
# currency                       0
# currency_other             27897
# income_context             25061
# country                        0
# us_state                    5034
# city                          82
# total_experience               0
# field_experience               0
# education_level              223
# gender                       171
# race                         177
# dtype: int64

# %%
import re

# Define a function to filter and clean numeric strings
def clean_numeric_column(column):
    # Use regex to keep only valid numeric strings (including commas)
    column_cleaned = column.astype(str).apply(lambda x: re.sub(r'[^\d.,-]', '', x))
    # Convert to numeric, coercing errors
    return pd.to_numeric(column_cleaned.str.replace(',', ''), errors='coerce')

# Apply the cleaning function to the relevant columns
df['annual_salary'] = clean_numeric_column(df['annual_salary'])
df['additional_compensation'] = clean_numeric_column(df['additional_compensation'])

# %%
# Create a distribution plot for annual salary
import matplotlib.pyplot as plt
import seaborn as sns

# Create a box plot for annual salary
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['annual_salary'])
plt.title('Box Plot of Annual Salary')
plt.xlabel('Annual Salary')
plt.show()

# box plot for additional_compensation  
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['additional_compensation'])
plt.title('Box Plot of additional_compensation')
plt.xlabel('additional_compensation')
plt.show()

# %%
# Create count plots for specified columns
columns_to_plot = ['gender', 'education_level', 'field_experience', 'total_experience', 'age']
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']

plt.figure(figsize=(15, 10))

for i, column in enumerate(columns_to_plot):
    plt.subplot(3, 2, i + 1)
    sns.countplot(data=df, x=column, palette=[colors[i]])
    plt.title(f'Count Plot of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# Print min and max dates using the timestamp column
min_date = df['timestamp'].min()
max_date = df['timestamp'].max()

print(f"Minimum date: {min_date}")
print(f"Maximum date: {max_date}")
# Out:
# Minimum date: 1/11/2022 13:26:41
# Maximum date: 9/9/2024 18:43:02

# %% [markdown]
# **Question:** How would you describe the "state" of this dataset? Be specific and detailed in your answer. (Think paragraphs rather than sentences).
#
# ### State of the Dataset
#
# This dataset consists of 25,326 unique responses, collected between January 11, 2022, and September 9, 2024. It covers a range of factors related to demographics, job roles, experience levels, compensation, and geographical distribution. Given the broad timeframe, this dataset captures salary trends and workforce characteristics over nearly three years.
#
# #### 1. Overview of Data Composition
# The dataset contains a mix of categorical, numerical, and text-based data, with some fields showing significant diversity in responses:
#
# - **Demographics:**
#   - Age is grouped into 7 categories, and education level has 6 distinct values.
#   - Gender (5 unique values) and race (51 unique values) suggest representation from different backgrounds.
#
# - **Job & Experience Information:**
#   - Industries (1,220 unique values) and job titles (14,377 unique values) highlight a wide range of professions.
#   - Total experience and field experience are structured into 8 categories each, making them easier to analyze.
#
# - **Geographical Data:**
#   - The dataset includes responses from 382 unique countries, with 137 distinct U.S. states and 4,841 different cities.
#
# - **Compensation Details:**
#   - Annual salary has 4,319 unique values, while additional compensation (bonuses, stock options, etc.) has 848 variations.
#   - Salaries are reported in 11 different currencies, requiring standardization.
#
# #### 2. Missing Data Challenges
# Some fields contain a significant number of missing values, which need to be handled carefully:
#
# - **Highly Incomplete Columns:**
#   - Job Title Context (82% missing) and Income Context (99% missing) suggest that many respondents did not provide additional details about their job or income structure. These fields may not be useful for modeling.
#   - Currency Other (99% missing) indicates that nearly all respondents selected a predefined currency, making this column redundant.
#
# - **Moderately Missing Fields:**
#   - Additional compensation (29% missing) is likely due to respondents without bonuses or stock-based income.
#   - U.S. State (5,034 missing values) is expected, as this column only applies to U.S. respondents.
#   - Education level, gender, and race each have a small percentage of missing values, which can be imputed or categorized as "Unknown" to avoid data loss.
#
# #### 3. Outliers & Data Distributions
# - Several extreme salary values were detected, with some exceeding billions, which is unrealistic and could distort analysis. These outliers will need to be capped or removed.
# - Additional compensation also has extreme values, with some responses exceeding $100 million, which may be errors or outliers.
# - Gender distribution is unbalanced, with a significantly higher number of responses from women compared to other gender categories.
# - Certain experience and education groups are overrepresented, which could influence trends in the dataset.

# %% [markdown]
# #### The Plan

# %% [markdown]
# Now, it is time to plan how you will clean up the dataset. You **are not** allowed to use any machine learning technique to clean the data. (No SMOTE! No machine learning! Or anything like that!)
#
# **Question:** Based on your EDA above, detail how you would clean up this dataset.
# Things to consider: (This is not an exhaustive list)
# - Are there columns that can't be effectively cleaned? If so, why?
# - Are there columns that genuinely won't have a data value?
# - Does it make sense to segment the dataset based on specific columns when determining how to handle the missing values?
# - Are outliers a factor in this dataset?
#
# Remember preserving as much of the data as possible is the goal. That means dropping rows with a missing value somewhere might not be the best idea.
#
#
# Here's a revised plan written in a more natural, human-friendly way while keeping the same headings:
#
# `Plan`
#
# **Columns That Can't Be Effectively Cleaned**
# - Job Title: With over 14,000 unique values, complete standardization isn't practical. However, we can keep the original titles since they provide valuable context for analysis.
# - Industry: Some industries are too niche for grouping, but we can standardize obvious variations (e.g., "Tech" vs "Technology").
# - Country: While there are many variations (US, USA, United States), we can standardize these to common formats.
# - City: With 4,800+ unique values, we'll focus on basic formatting and spelling corrections rather than deep cleaning.
#
# **Columns That Genuinely Won't Have a Data Value**
# - Job Title Context: Since this field has limited responses and isn't crucial for analysis, we can drop it entirely.
# - Additional Compensation: Rather than treating missing values as truly missing, we'll assume they represent $0 compensation.
# - US State: Will be missing for non-US respondents - this is expected and shouldn't be treated as missing data.
# - Currency: We'll standardize all monetary values to USD, eliminating the need for separate currency fields.
#
# **Handling Outliers**
# - Salary: Use IQR method to identify and remove extreme outliers while preserving legitimate high earners.
# - Additional Compensation: Apply IQR method similar to salary to remove unrealistic values.
# - Experience: Convert text ranges (e.g., "5-7 years") to ordinal values for better analysis.
# - Education: Create standardized ordinal mapping for education levels.
#
# **Segmentation for Handling Missing Values**
# - Categorical Variables: Convert to appropriate numeric formats
#   - Experience levels → Ordinal values (0-8)
#   - Education levels → Ordinal values
#   - Gender → Categorical encoding
# - Race/Ethnicity: Create binary columns for each category
# - Location Data: Standardize country names and handle state/city relationships
# - Salary Data: Convert all values to USD before analysis
#
# This revised plan takes a more comprehensive approach to data preparation, focusing not just on cleaning but also on transforming the data into a format suitable for analysis. The goal is to preserve as much useful information as possible while making the dataset more consistent and analysis-ready.

# %% [markdown]
# #### Implementation

# %% [markdown]
# Based on the plan the you described above, go ahead and clean up the dataset.
#
# [Add as many code cell below here as needs]

# %%
df.columns
# Out:
# Index(['timestamp', 'age', 'industry', 'job_title', 'job_title_context',
#        'annual_salary', 'additional_compensation', 'currency',
#        'currency_other', 'income_context', 'country', 'us_state', 'city',
#        'total_experience', 'field_experience', 'education_level', 'gender',
#        'race'],
#       dtype='object')

# %%
# Converting the age column to ordinal
age_bands = ['under 18', '18-24', '25-34', '35-44', '45-54', '55-64', '65 or over']
name_dict = {name: i+1 for i, name in enumerate(age_bands)}

df.age = df.age.map(name_dict)
df.sample(5)
# Out:
#                 timestamp  age                              industry  \
# 8029   4/27/2021 15:30:31    4          Education (Higher Education)
# 15565  4/28/2021 17:11:18    3                Transport or Logistics
# 8183   4/27/2021 15:42:57    2         Education (Primary/Secondary)
# 12230   4/28/2021 8:57:54    2  Government and Public Administration
# 24734   5/5/2021 18:45:25    4                     Recruitment or HR
#
#                       job_title  \
# 8029         EU project manager
# 15565  European Quality Manager
# 8183                Art Teacher
# 12230          Press assistant
# 24734             HR Generalist
#
#                                        job_title_context  annual_salary  \
# 8029   Organisation, admin and coordination for EU-fu...          60000
# 15565                                                NaN          65000
# 8183                                                 NaN          30000
# ...

# %%
df.industry.fillna('Other', inplace=True)
df.isna().sum()
# Out:
# timestamp                      0
# age                            0
# industry                       0
# job_title                      1
# job_title_context          20835
# annual_salary                  0
# additional_compensation     7315
# currency                       0
# currency_other             27897
# income_context             25061
# country                        0
# us_state                    5034
# city                          82
# total_experience               0
# field_experience               0
# education_level              223
# gender                       171
# race                         177
# dtype: int64

# %%
df[df.job_title.isna()]
# Out:
#                  timestamp  age                                      industry  \
# 27996  11/29/2023 19:59:34    2  I'm currently a student and don't have a job
#
#       job_title           job_title_context  annual_salary  \
# 27996       NaN  I don't have one right now              0
#
#        additional_compensation currency currency_other  \
# 27996                      0.0      USD            NaN
#
#                      income_context country      us_state city  \
# 27996  There is no income right now   U.S.A  Pennsylvania  NaN
#
#       total_experience field_experience education_level gender  \
# 27996      2 - 4 years      2 - 4 years    Some college    Man
#
#                             race
# 27996  Black or African American

# %%
# dropping the rows with missing values from the job_title column
df = df.dropna(subset=['job_title'])
df.isna().sum()
# Out:
# timestamp                      0
# age                            0
# industry                       0
# job_title                      0
# job_title_context          20835
# annual_salary                  0
# additional_compensation     7315
# currency                       0
# currency_other             27896
# income_context             25061
# country                        0
# us_state                    5034
# city                          81
# total_experience               0
# field_experience               0
# education_level              223
# gender                       171
# race                         177
# dtype: int64

# %%
# Dropping 'job_title_context' column as it has too many missing values
df = df.drop(columns=['job_title_context'])
df.isna().sum()
# Out:
# timestamp                      0
# age                            0
# industry                       0
# job_title                      0
# annual_salary                  0
# additional_compensation     7315
# currency                       0
# currency_other             27896
# income_context             25061
# country                        0
# us_state                    5034
# city                          81
# total_experience               0
# field_experience               0
# education_level              223
# gender                       171
# race                         177
# dtype: int64

# %%
! pip install pycountry fuzzywuzzy pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import pycountry
from fuzzywuzzy import process

# Get a dictionary of all official currency names mapped to their ISO 4217 codes
all_currency_names = {c.name: c.alpha_3 for c in pycountry.currencies}
print(all_currency_names)


# Function to standardize currency names
def get_currency_code(raw_name):
    raw_name = raw_name.strip()
         
    
    if raw_name in all_currency_names:
        return all_currency_names[raw_name]

    # Use fuzzy matching to find the closest valid currency name
    best_match, score = process.extractOne(raw_name, all_currency_names.keys())
    if score > 80:  # Confidence threshold
        return all_currency_names[best_match]
    
    for key, value in all_currency_names.items():
        if raw_name in value:
            return value
    
    return None

# Apply currency standardization to create a new '_currency' column
df['_currency_other'] = df['currency_other'].apply(lambda x: get_currency_code(x) if pd.notnull(x) else None)
# Out:
# {'UAE Dirham': 'AED', 'Afghani': 'AFN', 'Lek': 'ALL', 'Armenian Dram': 'AMD', 'Netherlands Antillean Guilder': 'ANG', 'Kwanza': 'AOA', 'Argentine Peso': 'ARS', 'Australian Dollar': 'AUD', 'Aruban Florin': 'AWG', 'Azerbaijan Manat': 'AZN', 'Convertible Mark': 'BAM', 'Barbados Dollar': 'BBD', 'Taka': 'BDT', 'Bulgarian Lev': 'BGN', 'Bahraini Dinar': 'BHD', 'Burundi Franc': 'BIF', 'Bermudian Dollar': 'BMD', 'Brunei Dollar': 'BND', 'Boliviano': 'BOB', 'Mvdol': 'BOV', 'Brazilian Real': 'BRL', 'Bahamian Dollar': 'BSD', 'Ngultrum': 'BTN', 'Pula': 'BWP', 'Belarusian Ruble': 'BYN', 'Belize Dollar': 'BZD', 'Canadian Dollar': 'CAD', 'Congolese Franc': 'CDF', 'WIR Euro': 'CHE', 'Swiss Franc': 'CHF', 'WIR Franc': 'CHW', 'Unidad de Fomento': 'CLF', 'Chilean Peso': 'CLP', 'Yuan Renminbi': 'CNY', 'Colombian Peso': 'COP', 'Unidad de Valor Real': 'COU', 'Costa Rican Colon': 'CRC', 'Peso Convertible': 'CUC', 'Cuban Peso': 'CUP', 'Cabo Verde Escudo': 'CVE', 'Czech Koruna': 'CZK', 'Djibouti Franc': 'DJF',
# ...

# %%
df[df.currency_other.notnull()][['_currency_other', 'currency_other']].sample(15)
# Out:
#       _currency_other     currency_other
# 603               ARS     Peso Argentino
# 8087              TRY                TRY
# 11793             SAR                AUD
# 9921             None                  -
# 6765             None                Bdt
# 4780             None           BRL (R$)
# 20373            None                Ils
# 23490             KRW                KRW
# 21240             MYR                MYR
# 11788             USD                USD
# 15160             BRL                BRL
# 10374            None  Taiwanese dollars
# 27841             PLN                PLN
# 25613             DKK                DKK
# 27902             COP                COP

# %%
# read the currency conversion rates json file
conversion_rates = pd.read_json('conversion_rates.json')
exchange_rates_dict = conversion_rates.set_index('Currency').to_dict()['Exchange_Rate']
exchange_rates_dict
# Out:
# {'USD': 1.0,
#  'CAD': 1.4293,
#  'GBP': 0.8063,
#  'EUR': 0.9682000000000001,
#  'AUD': 1.5948,
#  'NZD': 1.7666,
#  'CHF': 0.9098,
#  'SEK': 10.942,
#  'JPY': 151.4173,
#  'ZAR': 18.4142,
#  'INR': 87.6525,
#  'SGD': 1.3544,
#  'NOK': 11.2457,
#  'DKK': 7.2235,
#  'MYR': 4.4405,
#  'PLN': 4.0621,
#  'BRL': 5.7974,
#  'ARS': 1053.2198,
#  'PHP': 58.1128,
#  'CZK': 24.3174,
#  'MXN': 20.5722,
#  'THB': 33.8801,
#  'SAR': 3.75,
#  'HKD': 7.7909,
#  'KRW': 1454.1557,
#  'ILS': 3.5581,
#  'TRY': 35.9912,
#  'IDR': 16288.4658,
#  'CNY': 7.2882,
#  'BND': 1.3544,
#  'TTD': 6.7628,
#  'LKR': 297.2902,
#  'COP': 4122.87}

# %%
sample_indexes = df[df.currency == 'Other'].sample(5).index
print("Bedore standardization:")
print(df.loc[sample_indexes, ['currency', 'currency_other', '_currency_other']])

df[df.currency == 'Other'] = df[df.currency == 'Other'].assign(currency=df['_currency_other'])

print("After standardization:")
print(df.loc[sample_indexes, ['currency', 'currency_other', '_currency_other']])
# Out:
# Bedore standardization:
#       currency            currency_other _currency_other
# 15160    Other                       BRL             BRL
# 25548    Other                THAI  BAHT             THB
# 9847     Other  NIS (new Israeli shekel)             ILS
# 11610    Other                       Nok            None
# 7545     Other                       Php            None
# After standardization:
#       currency            currency_other _currency_other
# 15160      BRL                       BRL             BRL
# 25548      THB                THAI  BAHT             THB
# 9847       ILS  NIS (new Israeli shekel)             ILS
# 11610     None                       Nok            None
# 7545      None                       Php            None

# %%
def convert_to_usd(row, column_name='annual_salary'):
    # If the currency is USD, return the original amount
    if row['currency'] == 'USD':
        return row[column_name]
    
    # If the currency is not USD, look up the exchange rate
    exchange_rate = exchange_rates_dict.get(row['currency'])
    if exchange_rate is None:
        return None
    
    return row[column_name] / exchange_rate

# Apply the conversion to create a new 'annual_salary_usd' column
df['annual_salary_usd'] = df.apply(lambda row: convert_to_usd(row, 'annual_salary'), axis=1)
df['additional_compensation_usd'] = df.apply(lambda row: convert_to_usd(row, 'additional_compensation'), axis=1)

df[df.currency != 'USD'][['annual_salary', 'currency', 'annual_salary_usd', 'additional_compensation', 'additional_compensation_usd']].sample(5)
# Out:
#        annual_salary currency  annual_salary_usd  additional_compensation  \
# 22870          60000  AUD/NZD                NaN                      0.0
# 27997          80000  AUD/NZD                NaN                  45000.0
# 16615          42000      GBP       52089.792881                      NaN
# 16060          50000      GBP       62011.658192                      0.0
# 10051          64000      CAD       44777.163647                      NaN
#
#        additional_compensation_usd
# 22870                          NaN
# 27997                          NaN
# 16615                          NaN
# 16060                          0.0
# 10051                          NaN

# %%
# dropping annual_salary, additional_compensation, currency_other, income_context, _currency_other, currency columns

df.drop(columns=['annual_salary', 'additional_compensation', 'currency_other', 'income_context', '_currency_other', 'currency'], inplace=True)
df.isna().sum()
# Out:
# timestamp                         0
# age                               0
# industry                          0
# job_title                         0
# country                           0
# us_state                       5034
# city                             81
# total_experience                  0
# field_experience                  0
# education_level                 223
# gender                          171
# race                            177
# annual_salary_usd               541
# additional_compensation_usd    7665
# dtype: int64

# %%
df.us_state.fillna('Non US State', inplace=True)
df.city.fillna('Not specified', inplace=True)
df.isna().sum()
# Out:
# timestamp                         0
# age                               0
# industry                          0
# job_title                         0
# country                           0
# us_state                          0
# city                              0
# total_experience                  0
# field_experience                  0
# education_level                 223
# gender                          171
# race                            177
# annual_salary_usd               541
# additional_compensation_usd    7665
# dtype: int64

# %%
df.education_level.fillna('Not specified', inplace=True)
print(df.education_level.value_counts())

education_levels = {
    "Not specified": 0,
    "College degree": 1,
    "Master's degree": 2,
    "Some college": 3,
    "PhD": 4,
    "Professional degree (MD, JD, etc.)": 5,
    "High School": 6
}

df.education_level = df.education_level.map(education_levels)
df.isna().sum()
# Out:
# education_level
# College degree                        13536
# Master's degree                        8879
# Some college                           2074
# PhD                                    1427
# Professional degree (MD, JD, etc.)     1325
# High School                             643
# Not specified                           223
# Name: count, dtype: int64
# timestamp                         0
# age                               0
# industry                          0
# job_title                         0
# country                           0
# us_state                          0
# city                              0
# total_experience                  0
# field_experience                  0
# education_level                   0
# gender                          171
# race                            177
# annual_salary_usd               541
# additional_compensation_usd    7665
# dtype: int64

# %%
# Replacing Other or prefer not to answer, and null values with 'prefer not to answer'

df.gender.fillna('Prefer not to answer', inplace=True)
df.gender.replace({'Other or prefer not to answer': 'Prefer not to answer'}, inplace=True)

print(df.gender.value_counts())

df.isna().sum()
# Out:
# gender
# Woman                   21389
# Man                      5501
# Non-binary                747
# Prefer not to answer      470
# Name: count, dtype: int64
# timestamp                         0
# age                               0
# industry                          0
# job_title                         0
# country                           0
# us_state                          0
# city                              0
# total_experience                  0
# field_experience                  0
# education_level                   0
# gender                            0
# race                            177
# annual_salary_usd               541
# additional_compensation_usd    7665
# dtype: int64

# %%
df.race.fillna('Another option not listed here or prefer not to answer', inplace=True)

# Define the master list of races
race_master_list = [
    "Asian or Asian American",
    "Black or African American",
    "Hispanic, Latino, or Spanish origin",
    "Middle Eastern or Northern African",
    "Native American or Alaska Native",
    "White",
    "Another option not listed here or prefer not to answer"
]

# Create binary columns for each race in the master list
for race in race_master_list:
    df[race] = df['race'].apply(lambda x: 1 if race in x else 0)


# Drop the original
df.drop(columns = ['race'], inplace=True)

df.head()
# Out:
#             timestamp  age                       industry  \
# 0  4/27/2021 11:02:10    3   Education (Higher Education)
# 1  4/27/2021 11:02:22    3              Computing or Tech
# 2  4/27/2021 11:02:38    3  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41    3                     Nonprofits
# 4  4/27/2021 11:02:42    3  Accounting, Banking & Finance
#
#                                   job_title         country        us_state  \
# 0        Research and Instruction Librarian   United States   Massachusetts
# 1  Change & Internal Communications Manager  United Kingdom    Non US State
# 2                      Marketing Specialist              US       Tennessee
# 3                           Program Manager             USA       Wisconsin
# 4                        Accounting Manager              US  South Carolina
#
#           city total_experience field_experience  education_level      gender  \
# ...

# %%
df.isna().sum()
# Out:
# timestamp                                                    0
# age                                                          0
# industry                                                     0
# job_title                                                    0
# country                                                      0
# us_state                                                     0
# city                                                         0
# total_experience                                             0
# field_experience                                             0
# education_level                                              0
# gender                                                       0
# annual_salary_usd                                          541
# additional_compensation_usd                               7665
# Asian or Asian American                                      0
# Black or African American                                    0
# ...

# %%
df.additional_compensation_usd.fillna(0, inplace=True)

# drop null based on annual_salary_usd                                          
df = df.dropna(subset=['annual_salary_usd'])

df.isna().sum()
# Out:
# timestamp                                                 0
# age                                                       0
# industry                                                  0
# job_title                                                 0
# country                                                   0
# us_state                                                  0
# city                                                      0
# total_experience                                          0
# field_experience                                          0
# education_level                                           0
# gender                                                    0
# annual_salary_usd                                         0
# additional_compensation_usd                               0
# Asian or Asian American                                   0
# Black or African American                                 0
# Hispanic, Latino, or Spanish origin                       0
# ...

# %%
total_experience = df.total_experience.unique()
field_experience = df.field_experience.unique()

years = set(total_experience) and set(field_experience)
years
# Out:
# {'1 year or less',
#  '11 - 20 years',
#  '2 - 4 years',
#  '21 - 30 years',
#  '31 - 40 years',
#  '41 years or more',
#  '5-7 years',
#  '8 - 10 years'}

# %%
years_ordinals = {'1 year or less' : 0,
 '11 - 20 years': 5,
 '2 - 4 years': 2,
 '21 - 30 years': 6,
 '31 - 40 years': 7,
 '41 years or more': 8,
 '5-7 years' : 3,
 '8 - 10 years' : 4}

df.total_experience = df.total_experience.map(years_ordinals)
df.field_experience = df.field_experience.map(years_ordinals)

df.sample(5)
# Out:
#                 timestamp  age                              industry  \
# 5829   4/27/2021 13:24:59    3          Education (Higher Education)
# 2540   4/27/2021 11:46:14    2                            Nonprofits
# 19391   4/29/2021 9:23:07    4                     Computing or Tech
# 15237  4/28/2021 16:45:49    3              Library at a University
# 18035  4/28/2021 22:18:42    2  Government and Public Administration
#
#                                                job_title        country  \
# 5829             Coordinator of Instructional Technology            USA
# 2540                                      Grants Manager   United Sates
# 19391                                 Senior UX Designer            USA
# 15237  User Experience and Virtual Reference Coordina...  United States
# 18035                        Asset Forfeiture Specialist            USA
#
#          us_state         city  total_experience  field_experience  \
# ...

# %%
# Checkin for outliers in the dataset for annual_salary_usd and additional_compensation_usd
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.boxplot(x=df['annual_salary_usd'])
plt.title('Box Plot of Annual Salary in USD')
plt.xlabel('Annual Salary in USD')

plt.subplot(2, 2, 2)
sns.boxplot(x=df['additional_compensation_usd'])
plt.title('Box Plot of Additional Compensation in USD')
plt.xlabel('Additional Compensation in USD')

plt.tight_layout()
plt.show()

# %%
# Removing outliers from the dataset for annual_salary_usd and additional_compensation_usd using IQR method
Q1 = df['annual_salary_usd'].quantile(0.25)
Q3 = df['annual_salary_usd'].quantile(0.75)
IQR = Q3 - Q1

df = df[(df['annual_salary_usd'] >= (Q1 - 1.5 * IQR)) & (df['annual_salary_usd'] <= (Q3 + 1.5 * IQR))]
print(df.shape)

Q1 = df['additional_compensation_usd'].quantile(0.25)
Q3 = df['additional_compensation_usd'].quantile(0.75)
IQR = Q3 - Q1

df = df[(df['additional_compensation_usd'] >= (Q1 - 1.5 * IQR)) & (df['additional_compensation_usd'] <= (Q3 + 1.5 * IQR))]
print(df.shape)
# Out:
# (26416, 20)
# (23224, 20)

# %%
# Checkin for outliers in the dataset for annual_salary_usd and additional_compensation_usd
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.boxplot(x=df['annual_salary_usd'])
plt.title('Box Plot of Annual Salary in USD')
plt.xlabel('Annual Salary in USD')

plt.subplot(2, 2, 2)
sns.boxplot(x=df['additional_compensation_usd'])
plt.title('Box Plot of Additional Compensation in USD')
plt.xlabel('Additional Compensation in USD')

plt.tight_layout()
plt.show()

# %%
df.sample(5)
# Out:
#                 timestamp  age                      industry  \
# 12712  4/28/2021 10:48:12    3                       Ed Tech
# 18226  4/28/2021 23:12:52    3             Computing or Tech
# 22006  4/30/2021 17:21:05    5  Education (Higher Education)
# 24692   5/5/2021 17:57:03    3                      MedComms
# 15537  4/28/2021 17:10:21    4             Recruitment or HR
#
#                       job_title        country      us_state  \
# 12712  Junior Software Engineer             US    California
# 18226        Software Developer  United States          Utah
# 22006                Instructor            USA        Oregon
# 24692            Medical Writer             UK  Non US State
# 15537      HR Diversity Manager             US         Texas
#
#                                            city  total_experience  \
# 12712  Remote. Company is in Boston, I am in SF                 3
# 18226                                     Provo                 3
# ...

# %%
df.to_csv('analytics_usable_survey_data.csv', index=False)

# %% [markdown]
# #### Reflection
# Write a short reflection (400-500 words) answering the following:
# - What were the biggest issues you encountered in the messy dataset?
# - How did cleaning the dataset improve its usability for machine learning?
# - What would happen if we trained a model on the messy dataset vs. the cleaned one?
# - Do you feel you skewed or biased the dataset while cleaning it?
#
#
# `Reflection`
#
# The biggest challenges in this messy dataset were handling inconsistent currency values, standardizing experience levels, and dealing with outliers in salary data. The salary and compensation fields contained values in different currencies that needed to be converted to USD for meaningful analysis. Additionally, the experience fields had categorical values (like "5-7 years") that needed to be transformed into ordinal numbers for machine learning purposes.
#
# The cleaning process significantly improved the dataset's usability for machine learning by addressing these issues. By converting all monetary values to USD, removing outliers using the IQR method, and converting categorical experience levels to numerical values, we created more consistent and machine-learning-friendly features. The removal of null values and standardization of formats means that models won't be confused by inconsistent or missing data.
#
# If we had trained a model on the messy dataset, it would likely have produced unreliable results. The presence of multiple currencies would have skewed salary predictions, while categorical experience data would have been difficult for models to interpret properly. Outliers could have disproportionately influenced the model's learning, leading to poor generalization. The cleaned dataset, on the other hand, provides more reliable features that models can effectively learn from.
#
# Regarding bias, while some data was removed through cleaning (particularly through outlier removal and handling null values), the cleaning process focused on improving data quality rather than introducing systematic bias. The ordinal mapping of experience levels preserved the relative relationships in the data, and the outlier removal was based on statistical methods (IQR) rather than arbitrary decisions. However, it's worth noting that any data cleaning process inherently involves some level of data reduction, which could potentially impact the representation of certain groups in the dataset.

# %% [markdown]
# ## Deliverables
# Upload your Jupyter Notebook to your GitHub repo and then provide a link to that repo in Worlclass.
